# %% [markdown]
# # Пример использования Estimators.py

# %% [markdown]
# ### Установка необходимых версий библиотек

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ### Импорт библиотек и функций из файла Estimators.py

# %%
import pandas as pd
from Estimators import *
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Без учета пересдач

# %% [markdown]
# ### Инициализация матрицы оценок студентов

# %%
data = pd.read_csv('example_data_s5_u4.csv')

marks = data.values[:, 1:]

# %% [markdown]
# ### Оценка параметров с помощью MAP

# %%
map_estimator(marks)
# Out:
# (0    0.503868
#  1    0.306500
#  2    0.514678
#  3    0.503868
#  4    0.649746
#  Name: map_perfomance, dtype: float64,
#  0    0.464192
#  1    0.482185
#  2    0.593200
#  3    0.593200
#  Name: map_difficulty, dtype: float64)

# %% [markdown]
# ### Оценка параметров с помощью MСMC

# %%
mcmc_estimator(marks)
# Out:
# Only 20 samples per chain. Reliable r-hat and ESS diagnostics require longer chains for accurate estimate.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [performance, difficulty]
# Sampling 4 chains for 1_000 tune and 20 draw iterations (4_000 + 80 draws total) took 38 seconds.
# The number of samples is too small to check convergence reliably.
# (0    0.512472
#  1    0.359569
#  2    0.514209
#  3    0.486687
#  4    0.564509
#  Name: mcmc_performance, dtype: float64,
#  0    0.476629
#  1    0.485677
#  2    0.553754
#  3    0.573825
#  Name: mcmc_difficulty, dtype: float64)

# %% [markdown]
# ### Оценка параметров с помощью MLE с scipy.optimize

# %%
mle_estimator(marks)
# Out:
# (0    0.503838
#  1    0.306489
#  2    0.514649
#  3    0.503838
#  4    0.649699
#  Name: mle_performance, dtype: float64,
#  0    0.464180
#  1    0.482173
#  2    0.593208
#  3    0.593208
#  Name: mle_difficulty, dtype: float64)

# %% [markdown]
# ## С учетом пересдач

# %%
data_retakes = pd.read_csv('example_data_retakes_s5_u5.csv')

marks_retakes = data_retakes.values[:, 1:]

# %% [markdown]
# ### Оценка параметров с помощью MAP

# %%
map_estimator(marks_retakes, retakes=True)
# Out:
# (0    0.610241
#  1    0.757732
#  2    0.417720
#  3    0.348484
#  4    0.376162
#  Name: map_perfomance, dtype: float64,
#  0    0.473350
#  1    0.383098
#  2    0.239087
#  3    0.674686
#  4    0.663572
#  Name: map_difficulty, dtype: float64)

# %% [markdown]
# ### Оценка параметров с помощью MСMC

# %%
mcmc_estimator(marks_retakes, retakes=True)
# Out:
# Only 20 samples per chain. Reliable r-hat and ESS diagnostics require longer chains for accurate estimate.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [performance, difficulty]
# Sampling 4 chains for 1_000 tune and 20 draw iterations (4_000 + 80 draws total) took 94 seconds.
# The number of samples is too small to check convergence reliably.
# (0    0.597786
#  1    0.683516
#  2    0.437769
#  3    0.389812
#  4    0.394288
#  Name: mcmc_performance, dtype: float64,
#  0    0.494472
#  1    0.431852
#  2    0.293436
#  3    0.630882
#  4    0.634096
#  Name: mcmc_difficulty, dtype: float64)

# %% [markdown]
# ### Оценка параметров с помощью MLE с scipy.optimize

# %%
mle_estimator(marks_retakes, retakes=True)
# Out:
# c:\Users\Vitalina\OneDrive\Рабочий стол\Work\Medics\Estimators.py:208: RuntimeWarning: divide by zero encountered in log
#   np.log(w1) + log_bern,
# (0    0.610348
#  1    0.757783
#  2    0.417851
#  3    0.348547
#  4    0.376288
#  Name: mle_performance, dtype: float64,
#  0    0.473392
#  1    0.383143
#  2    0.239125
#  3    0.674736
#  4    0.663613
#  Name: mle_difficulty, dtype: float64)
